# %%
from hdmf_zarr import NWBZarrIO

# %%
with NWBZarrIO("/root/capsule/data/test_dynamic_foraging_nwb/behavior.nwb.zarr", "r") as io:
    nwb = io.read()

# %%
nwb.acquisition["left_reward_delivery_time"].timestamps[:]
# Out:
# array([6823368.11248 , 6823409.83648 , 6823418.103488, 6823884.16448 ,
#        6823917.06048 , 6823948.502496, 6823954.21248 , 6823963.053504,
#        6823968.255488, 6823975.223488, 6824030.430496, 6824065.637504,
#        6824081.61248 , 6824090.10848 , 6824099.515488, 6824105.687488,
#        6824111.965504, 6824116.873504, 6824122.10048 , 6824126.675488,
#        6824134.386496, 6824138.570496, 6824150.80848 , 6824156.706496,
#        6824165.733504, 6824170.34048 , 6824174.778496, 6824180.841504,
#        6824192.555488, 6824196.722496, 6824203.53248 , 6824207.859488,
#        6824222.641504, 6824229.278496, 6824270.899488, 6824335.753504,
#        6824360.213504, 6824382.686496, 6824394.081504, 6824410.594496,
#        6824693.559488, 6824715.610496, 6824726.334496, 6824734.08048 ,
#        6824738.567488, 6824743.60048 , 6824749.16848 , 6824757.266496,
#        6824762.213504, 6824774.683488, 6824781.56048 , 6824794.099488,
# ...

# %%
nwb.trials[:]
# Out:
#        start_time     stop_time  animal_response  rewarded_historyL  \
# id
# 0    6.823328e+06  6.823332e+06                1              False
# 1    6.823334e+06  6.823337e+06                1              False
# 2    6.823343e+06  6.823346e+06                1              False
# 3    6.823349e+06  6.823352e+06                1              False
# 4    6.823357e+06  6.823360e+06                1              False
# ..            ...           ...              ...                ...
# 616  6.827803e+06  6.827807e+06                2              False
# 617  6.827808e+06  6.827811e+06                0               True
# 618  6.827812e+06  6.827816e+06                2              False
# 619  6.827820e+06  6.827824e+06                2              False
# 620  6.827826e+06  6.827830e+06                2              False
#
#      rewarded_historyR  delay_start_time  goCue_start_time  bait_left  \
# id
# ...
